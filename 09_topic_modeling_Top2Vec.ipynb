# %%
# !pip install top2vec
# !pip install top2vec[sentence_transformers]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 21.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039174 sha256=0c35fdc8f1a725b162b05eafb6c59155add24c584f6056f4a847eadd7df5cf70
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
# ...
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82807 sha256=714c8008a030a47d305f604f3ed30015e929ca2187831d430228ffa06af05f75
# ...

# %%
from top2vec import Top2Vec

# %%
import pandas as pd

# %%
# corpus: uniquement les textes d'annonces du fichier csv
df = pd.read_csv("./df_final.csv")
data = list(df['Annonces'])
data
# Out:
# ["Une personne de 24 ans, d'un extérieur agréable, ayant reçu de l'éducation, et joignant à cela les talens utiles à son sexe , tant en ceuture qu'en linge et broderie, et connoissant tous les détails d'un ménage, auquel elle se rendroit utile, desireroit se PLACEB près d'une personne seule, soit dans un comptoir ou pour tenir une maison quelconque. Elle sait bien    écrire et compter; elle accepteroit aussi une place de Femme-de-chambre, et consentiroit d'aller dans une ville de départe-ment, même en pays étranger. Elle fournira de très-bons ré-pondans. S'ad. par écrit ou de vive voix, mais sans en dire le sujet, rue S. Thomas-du-Louvre, vis-à-vis les écuries du ci-dev. ",
# ...

# %%
model = Top2Vec(data, speed="deep-learn")
# Out:
# 2023-09-09 09:53:18,191 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# 2023-09-09 09:53:21,491 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2023-09-09 09:57:12,798 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2023-09-09 09:57:50,444 - top2vec - INFO - Finding dense areas of documents
# INFO:top2vec:Finding dense areas of documents
# 2023-09-09 09:57:50,620 - top2vec - INFO - Finding topics
# INFO:top2vec:Finding topics

# %%
model.get_num_topics()
# Out:
# 24

# %%
topic_sizes, topic_nums = model.get_topic_sizes()

# %%
topic_words, word_scores, topic_nums = model.get_topics(24)

# %%
for scores in word_scores:
  print(scores)
# Out:
# [0.42946023 0.42624557 0.42068022 0.40482423 0.37151703 0.35877872
#  0.33904618 0.3377114  0.3320558  0.3240181  0.31860214 0.31543243
#  0.31231058 0.30951777 0.30830395 0.30020022 0.2949853  0.29013556
#  0.28441048 0.27883148 0.27816093 0.26979816 0.2657531  0.26495484
#  0.26116297 0.2608833  0.2596582  0.25888717 0.25220466 0.24941957
#  0.24329276 0.24097058 0.23164788 0.22213851 0.2152844  0.21399291
#  0.21398473 0.21106435 0.21027489 0.19569151 0.19468817 0.19362156
#  0.1929022  0.19104144 0.18842381 0.18785568 0.18549433 0.18346286
#  0.18314877 0.18311486]
# [0.4853998  0.46742386 0.44030315 0.41951096 0.41037503 0.35984507
#  0.35282332 0.34723425 0.3384804  0.33575988 0.31477594 0.31331837
#  0.30984882 0.30969226 0.30856004 0.30724743 0.3046726  0.301642
#  0.3012951  0.2933172  0.2800819  0.2692348  0.2663045  0.26468253
#  0.25526434 0.2521504  0.2517609  0.23713972 0.2348544  0.23413281
#  0.23311935 0.22783297 0.22660649 0.22248548 0.22043106 0.21928221
# ...

# %%
#creating colormap
import matplotlib as mpl
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

colors1 = ["lavender", "lightpink", "peachpuff"]
cmap1 = LinearSegmentedColormap.from_list("mycmap", colors1)

colors2 = ["darkseagreen", "darkgreen","mediumpurple", "salmon", "palevioletred","lavender", "lightpink", "peachpuff", "mintcream", "cadetblue", "thistle", "lightyellow", "mintcream", "powderblue"]
cmap2 = LinearSegmentedColormap.from_list("mycmap", colors2)

# %%
#topic_words, word_scores, topic_scores, topic_nums = model.search_topics(keywords=["media"], num_topics=5)
for topic in topic_nums:
    model.generate_topic_wordcloud(topic, background_color="white")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
topic_words, word_scores, topic_scores, topic_nums = model.search_topics(keywords=["femme"], num_topics=5)

# %%
topic_scores
# Out:
# array([0.30969227, 0.27329095, 0.2649548 , 0.26190972, 0.25114028])

# %%
words, word_scores = model.similar_words(keywords=["femme"], keywords_neg=[], num_words=20)
for word, score in zip(words, word_scores):
    print(f"{word} {score}")
# Out:
# lait 0.6914574777002842
# enfant 0.3595807063005629
# dont 0.33189895070191244
# six 0.3059438446155381
# tailleur 0.3003716487212766
# citoyenne 0.2868323135434556
# desirerait 0.2807782265083325
# hopital 0.27581300941373066
# gouvernante 0.27052840926309646
# divers 0.27013194977457394
# cher 0.2645492572048901
# vingt 0.26247332325688627
# dubois 0.2622210167339933
# autre 0.26074695902169326
# rue 0.2521655323411918
# femme 0.24924892392683243
# quarante 0.24536263907448796
# tenue 0.24485125024285537
# citoyen 0.2447175985120627
# bas 0.24457964698305978
